# %%
import folium
import json
import branca 
import pandas
import random

IFRAME_WIDTH_SETTING = 800
IFRAME_HEIGHT_SETTING = 400
MAX_IFRAME_WIDTH = 900

popupPrototype = """
<table width="100%"  style=" margin: auto;" border="0" align="center" cellpadding="0" cellspacing="0">

<!-- HEADER ROW WITH NEIGHBORHOOD and TRACT INFORMATION -->
<tr><td valign="top" align="left"> 

    <table width="100%" border="0" cellpadding="0" cellspacing="0" bgcolor="#FFFFFF">
      <tr>
        <td align="left" valign="middle" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 14px; color: #353535; padding-top:15px; padding-bottom:15px;">
		INFO
		</td>
      </tr>
	</table>
	
</td></tr>

<tr>

<!--------- LEFT TABLE - GROUP 1 on LEFT STARTS HERE -->
<td align="left" width="25%">
          
	<table width="95%" border="0" cellpadding="0" cellspacing="0">
            <tr>
              <td colspan="2"  align="left" bgcolor="#252525" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #EEEEEE; padding:5px; padding-right:0;">
                Census Data 
              </td>             
            </tr>
    
        <tr>
          <td width="18%" align="left" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
            Tract Population
          </td>
          <td width="18%" align="right" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
            4781
          </td>
        </tr>
    
        <tr>
          <td width="18%" align="left" bgcolor="#FFFFFF" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
            Black Population
          </td>
          <td width="18%" align="right" bgcolor="#FFFFFF" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
            4629
          </td>
        </tr>
    
        <tr>
          <td width="18%" align="left" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
            White Population
          </td>
          <td width="18%" align="right" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
            94
          </td>
        </tr>
    
        <tr>
          <td width="18%" align="left" bgcolor="#FFFFFF" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
            Native American Population
          </td>
          <td width="18%" align="right" bgcolor="#FFFFFF" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
            58
          </td>
        </tr>
    
        <tr>
          <td width="18%" align="left" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
            Asian Population
          </td>
          <td width="18%" align="right" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
            0
          </td>
        </tr>
    
      </table>
	  
	
<!--  table just ended -->	
</td>

<!--------- RIGHT TABLE - GROUP 2 on RIGHT STARTS HERE -->

<td align="left"  width="25%">
          
	<table width="95%" border="0" cellpadding="0" cellspacing="0">
            <tr>
              <td colspan="2"  align="left" bgcolor="#252525" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #EEEEEE; padding:5px; padding-right:0;">
                Census Data 
              </td>             
            </tr>
    
        <tr>
          <td width="18%" align="left" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
            Tract Population
          </td>
          <td width="18%" align="right" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
            4781
          </td>
        </tr>
    
        <tr>
          <td width="18%" align="left" bgcolor="#FFFFFF" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
            Black Population
          </td>
          <td width="18%" align="right" bgcolor="#FFFFFF" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
            4629
          </td>
        </tr>
    
        <tr>
          <td width="18%" align="left" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
            White Population
          </td>
          <td width="18%" align="right" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
            94
          </td>
        </tr>
    
        <tr>
          <td width="18%" align="left" bgcolor="#FFFFFF" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
            Native American Population
          </td>
          <td width="18%" align="right" bgcolor="#FFFFFF" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
            58
          </td>
        </tr>
    
        <tr>
          <td width="18%" align="left" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
            Asian Population
          </td>
          <td width="18%" align="right" bgcolor="#EEEEEE" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
            0
          </td>
        </tr>
    
      </table>
	  
	
<!--  table just ended -->	
</td>

</tr>
 
<tr>
    <td align="left" valign="middle" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 14px; color: #353535; padding:3%; padding-top:40px; padding-bottom:40px;">
      Sources: 2016 US Census Figures      
    </td>
  </tr>
  
</table>
"""



def betterPopupTop(feature):    
    return """
        <table width="100%"  style=" margin: auto;" border="0" align="center" cellpadding="0" cellspacing="0">

        <!-- HEADER ROW WITH NEIGHBORHOOD and TRACT INFORMATION -->
        <tr><td valign="top" align="left"> 

            <table width="100%" border="0" cellpadding="0" cellspacing="0" bgcolor="#FFFFFF">
              <tr>
                <td align="left" valign="middle" style="font-family: Verdana, Geneva, Helvetica, Arial, 
                sans-serif; font-size: 16px; color: #353535; padding-top:15px; padding-bottom:15px;">
                """ + "Tract: " + str(feature["NAMELSAD"]) + "<br />" + \
                "GEOID: " + str(feature["GEOID"]) + "<br />" + \
                "Neighborhood: " + str(feature["NEIGHBORHOOD_NAME"])  + """
                </td>
              </tr>
            </table>

        </td></tr>
        """

def betterPopupEnding():    
    return """
        </tr>

        <tr>
            <td align="left" valign="middle" style="font-family: Verdana, Geneva, Helvetica, Arial, 
            sans-serif; font-size: 10px; color: #353535; padding:3%; padding-top:40px; 
            padding-bottom:40px;">
              Sources: 2016 US Census Figures      
            </td>
          </tr>

        </table>
        """

def betterOneColumnStart(whichSide):
    if (whichSide == "LEFT"):
        return """
        <tr>
            <!--------- ONE GROUP START; table within table column -->
            <td align="left" width="25%" valign="top">

            <table width="95%" border="0" cellpadding="0" cellspacing="0">
        """
    else: 
        return """        
            <!--------- ONE GROUP START; table within table column -->
            <td align="left" width="25%" valign="top">

            <table width="95%" border="0" cellpadding="0" cellspacing="0">
        """

def betterOneColumnEnd():
    return "</table></td>"

def betterOneColumnHeader(headerText):
    return """
        <tr>
              <td colspan="2"  align="left" bgcolor="#252525" style="font-family: 
              Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #EEEEEE; 
              padding:5px; padding-right:0; font-weight: bold; ">
                """ + headerText + """ 
              </td>             
            </tr>
    """

def betterOneDataRow (feature, label, dataName, backgroundColor):
    return """
        <tr>
          <td width="18%" align="left" bgcolor="#""" + backgroundColor + """" style="font-family: Verdana, 
          Geneva, Helvetica, Arial, sans-serif; font-size: 10px; color: #252525; padding:5px; padding-right:0;">
            """ + label + """
          </td>
          <td width="18%" align="right" bgcolor="#""" + backgroundColor + """" style="font-family: Verdana, 
          Geneva, Helvetica, Arial, sans-serif; font-size: 10px; color: #252525; padding:5px; padding-left:0;">
            """ + str(feature[dataName]) + """
          </td>
        </tr>
    """



# popupTopHeader = """
# <table width="100%" class="maxW" style="max-width: 400px; margin: auto;" border="0" align="center" cellpadding="0" cellspacing="0">
# <tr><td valign="top" align="center"> 
# """

# tableTopHeader = """
#     <table width="100%" border="0" cellpadding="0" cellspacing="0" bgcolor="#FFFFFF">
#       <tr>
#         <td align="left" valign="middle" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 14px; color: #353535; padding:3%; padding-top:40px; padding-bottom:40px;">
# """

# popupBottomHeader = """
#   </td>
#   </tr>
#   <tr>
# """


# def onePopupColHeader(label1, label2, backgroundColor):
#     html = """
#         <td align="center">
#           <table width="94%" border="0" cellpadding="0" cellspacing="0">
#             <tr>
#               <td colspan="2"  align="left" bgcolor="#""" + backgroundColor + """" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #EEEEEE; padding:5px; padding-right:0;">
#                 """ + str(label1) + """ 
#               </td>
             
#             </tr>
#     """
    
#     return html

# def onePopupRow(feature, label, dataName, backgroundColor):
#     html = """
#         <tr>
#           <td width="18%" align="left" bgcolor="#""" + backgroundColor + """" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-right:0;">
#             """ + label + """
#           </td>
#           <td width="18%" align="right" bgcolor="#""" + backgroundColor + """" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 12px; color: #252525; padding:5px; padding-left:0;">
#             """ + str(feature[dataName]) + """
#           </td>
#         </tr>
#     """
    
#     return html


# popupBottomFooter = """
#       </table>
#     </td>
#   </tr>
#   <tr>
#     <td align="left" valign="middle" style="font-family: Verdana, Geneva, Helvetica, Arial, sans-serif; font-size: 14px; color: #353535; padding:3%; padding-top:40px; padding-bottom:40px;">
#       Sources: 2016 US Census Figures
#       <!-- using &nbsp; will prevent orphan words -->
#     </td>
#   </tr>
# </table>

# </td></tr>
# </table>
# """




def popupMaker(feature):
    return  betterPopupTop(feature) + \
            betterOneColumnStart("LEFT") + \
            betterOneColumnHeader("Census Data") + \
            betterOneDataRow(feature, 'Tract Population', 'POPULATION', 'EEEEEE') + \
            betterOneDataRow(feature, 'Black Population', 'BLACK_POPULATION', 'FFFFFF') + \
            betterOneDataRow(feature, 'White Population', 'WHITE_POPULATION', 'EEEEEE') + \
            betterOneDataRow(feature, 'Native American Population', 'NATIVE_POPULATION', 'FFFFFF') + \
            betterOneDataRow(feature, 'Asian Population', 'ASIAN_POPULATION', 'EEEEEE') + \
            betterOneColumnHeader("Opportunity Atlas Data") + \
            betterOneDataRow(feature, '% Staying in Tract as Adult', 'STAY_IN_TRACT_OF_BIRTH', 'EEEEEE') + \
            betterOneColumnHeader("Social Vulnerability Index Scores<br />(1.0 is most vulnerable)") + \
            betterOneDataRow(feature, 'Overall Vulnerability', 'SVI_OVERALL', 'EEEEEE') + \
            betterOneDataRow(feature, 'Socioeconomic', 'SVI_SOSEC', 'FFFFFF') + \
            betterOneDataRow(feature, 'Household Composition & Disability', 'SVI_HHCD', 'EEEEEE') + \
            betterOneDataRow(feature, 'Minority Status & Language', 'SVI_MSLANG', 'FFFFFF') + \
            betterOneDataRow(feature, 'Housing Type & Transportation', 'SVI_HTT', 'EEEEEE') + \
            betterOneColumnEnd() + \
            betterOneColumnStart("RIGHT") + \
            betterOneColumnHeader("BRFSS HEALTH OUTCOMES") + \
            betterOneDataRow(feature, 'BRFSS Population Figure', \
                           'BRFSS_TRACT_TOTPOP', 'FFDF65') + \
            betterOneDataRow(feature, 'Physical health not good for >=14 days among adults aged >=18 years', \
                           'PH_14DAYS', 'EEEEEE') + \
            betterOneDataRow(feature, 'Cancer (excluding skin cancer) among adults aged >=18 year', \
                           'CANCER_PCT', 'FFFFFF') + \
            betterOneDataRow(feature, 'All teeth lost among adults aged >=65 years', \
                           'TEETH_LOSS65', 'EEEEEE') + \
            betterOneDataRow(feature, 'Mental health not good for >=14 days among adults aged >=18 years', \
                           'MNTLHLTH_14DAYS', 'FFFFFF') + \
            betterOneDataRow(feature, 'Diagnosed diabetes among adults aged >=18 years', \
                           'DIABETES', 'EEEEEE') + \
            betterOneDataRow(feature, 'Stroke among adults aged >=18 years', \
                           'STROKE', 'FFFFFF') + \
            betterOneDataRow(feature, 'Coronary heart disease among adults aged >=18 years', \
                           'CHD', 'EEEEEE') + \
            betterOneDataRow(feature, 'High cholesterol among adults aged >=18 years who have been screened in the past 5 years', \
                           'HICHOL', 'FFFFFF') + \
            betterOneDataRow(feature, 'Chronic obstructive pulmonary disease among adults aged >=18 years', \
                           'COPD', 'EEEEEE') + \
            betterOneDataRow(feature, 'High blood pressure among adults aged >=18 years', \
                           'HIGHBP', 'FFFFFF') + \
            betterOneDataRow(feature, 'Arthritis among adults aged >=18 years', \
                           'ARTHRITIS', 'EEEEEE') + \
            betterOneDataRow(feature, 'Current asthma among adults aged >=18 years', \
                           'ASTHMA', 'FFFFFF') + \
            betterOneDataRow(feature, 'Chronic kidney disease among adults aged >=18 years', \
                           'CKD', 'EEEEEE') + \
            betterOneColumnEnd() + \
            betterOneColumnStart("RIGHT") + \
            betterOneColumnHeader("UAB ED/Urgent Encounters (2015-2020)") + \
            betterOneDataRow(feature, 'Total Encounters This Tract', \
                           'TOTAL_TRACT_ENCS', '00FEFE') + \
            betterOneDataRow(feature, 'Black, Neoplasm/Cancer', \
                           'UAB_BLKCAT_NEOPLASM', 'EEEEEE') + \
            betterOneDataRow(feature, 'White, Neoplasm/Cancer', \
                           'UAB_WHTCAT_NEOPLASM', 'EEEEEE') + \
            betterOneDataRow(feature, 'Black, Respiratory', \
                           'UAB_BLKCAT_RESPIR', 'FFFFFF') + \
            betterOneDataRow(feature, 'White, Respiratory', \
                           'UAB_WHTCAT_RESPIR', 'FFFFFF') + \
            betterOneDataRow(feature, 'Black, Nervous System', \
                           'UAB_BLKCAT_NRVSYS', 'EEEEEE') + \
            betterOneDataRow(feature, 'White, Nervous System', \
                           'UAB_WHTCAT_NRVSYS', 'EEEEEE') + \
            betterOneDataRow(feature, 'Black, Skin', \
                           'UAB_BLKCAT_SKIN', 'FFFFFF') + \
            betterOneDataRow(feature, 'White, Skin', \
                           'UAB_WHTCAT_SKIN', 'FFFFFF') + \
            betterOneDataRow(feature, 'Black, Infectious/Parasitic Diseases', \
                           'UAB_BLKCAT_INFPARA', 'FFFFFF') + \
            betterOneDataRow(feature, 'White, Infectious/Parasitic Diseases', \
                           'UAB_WHTCAT_INFPARA', 'FFFFFF') + \
            betterOneDataRow(feature, 'Black, Blood/Immune Diseases', \
                           'UAB_BLKCAT_BLDIMU', 'FFFFFF') + \
            betterOneDataRow(feature, 'White, Blood/Immune Diseases', \
                           'UAB_WHTCAT_BLDIMU', 'FFFFFF') + \
            betterOneDataRow(feature, 'Black, Metabolic Diseases', \
                           'UAB_BLKCAT_METABOL', 'FFFFFF') + \
            betterOneDataRow(feature, 'White, Metabolic Diseases', \
                           'UAB_WHTCAT_METABOL', 'FFFFFF') + \
            betterOneDataRow(feature, 'Black, Mental/Behavioral Diseases', \
                           'UAB_BLKCAT_MENBEH', 'FFFFFF') + \
            betterOneDataRow(feature, 'White, Mental/Behavioral Diseases', \
                           'UAB_WHTCAT_MENBEH', 'FFFFFF') + \
            betterOneDataRow(feature, 'Black, Ear/Mastoid Diseases', \
                           'UAB_BLKCAT_EARMAST', 'FFFFFF') + \
            betterOneDataRow(feature, 'White, Ear/Mastoid Diseases', \
                           'UAB_WHTCAT_EARMAST', 'FFFFFF') + \
            betterOneDataRow(feature, 'Black, Eye/Adexa Diseases', \
                           'UAB_BLKCAT_EYEADEX', 'FFFFFF') + \
            betterOneDataRow(feature, 'White, Eye/Adexa Diseases', \
                           'UAB_WHTCAT_EYEADEX', 'FFFFFF') + \
            betterOneDataRow(feature, 'Black, Circulatory Diseases', \
                           'UAB_BLKCAT_CIRCUL', 'FFFFFF') + \
            betterOneDataRow(feature, 'White, Circulatory Diseases', \
                           'UAB_WHTCAT_CIRCUL', 'FFFFFF') + \
            betterOneDataRow(feature, 'Black, Digestive Diseases', \
                           'UAB_BLKCAT_DIGEST', 'FFFFFF') + \
            betterOneDataRow(feature, 'White, Digestive Diseases', \
                           'UAB_WHTCAT_DIGEST', 'FFFFFF') + \
            betterOneColumnEnd() + \
            betterPopupEnding()

################################## CENSUS TRACTS LAYER, CENSUS TRACT DATA ########################################
################################## CENSUS TRACTS LAYER, CENSUS TRACT DATA  #######################################
################################## CENSUS TRACTS LAYER, CENSUS TRACT DATA  #######################################


############### Get the Opportunity Atlas data for jefferson county #######################################
############### Get the Opportunity Atlas data for jefferson county #######################################
############### Get the Opportunity Atlas data for jefferson county #######################################

#columns are: "tract","Name","%_Staying_in_Same_Tract_as_Adults_rB_gP_p25"
#TELLING PANDAS TO KEEP tract as a string so leading zeroes remain
lst_str_cols = ['tract', 'Name']
# use dictionary comprehension to make dict of dtypes
dict_dtypes = {x : 'str'  for x in lst_str_cols}
opportunityStayInTractPercents = pandas.read_csv(
    "D:\\Environmental Justice Docs\\Opportunity atlas low income black all genders shown_tract_staytract_rB_gP_p25.csv",
     dtype=dict_dtypes)

def getOpportunityAtlasPercents(tractGEOID, whichField):    
    percentage = -1
    neighborhood = "N/A"
    rowzzz = opportunityStayInTractPercents[(opportunityStayInTractPercents.tract == tractGEOID)]
    for index, onerow in rowzzz.iterrows():
        if (whichField == "percentage"):
            percentage = onerow["%_Staying_in_Same_Tract_as_Adults_rB_gP_p25"]
        elif (whichField == "neighborhoodName"):
            neighborhood = onerow["Name"]
        
    if (whichField == "percentage"):
        answer = "N/A"
        if (percentage > 0):
            answer = str(round(percentage*100, 1)) + "%"
        return answer
    elif (whichField == "neighborhoodName"):
        return neighborhood

    
    
##########################  CDC Social Vulnerability Index Scores #############################
##########################  CDC Social Vulnerability Index Scores #############################
##########################  CDC Social Vulnerability Index Scores #############################


# From CDC Documentation on the 2018 SVI data set for Alabama census tracts
# Socioeconomic - RPL_THEME1
# Household Composition & Disability - RPL_THEME2
# Minority Status & Language - RPL_THEME3
# Housing Type & Transportation - RPL_THEME4
# Overall tract rankings: We summed the sums for each theme, ordered the tracts, and then calculated overall
# percentile rankings. Please note; taking the sum of the sums for each theme is the same as summing individual
# variable rankings. The overall tract summary ranking variable is RPL_THEMES

lst_str_cols2 = ['FIPS']
dict_dtypes2 = {x : 'str'  for x in lst_str_cols2}
cdcSVIDataset = pandas.read_csv(
    "D:\\Environmental Justice Docs\\Alabama 2018 CDC SVI.csv", dtype=dict_dtypes2)

def getCDC_SVI_Percents(tractGEOID, whichField):    
    cviScore = -1
    
    rowzzz = cdcSVIDataset[(cdcSVIDataset.FIPS == tractGEOID)]
    for index, onerow in rowzzz.iterrows():
        if (whichField == "overall"):  #overall
            cviScore = onerow["RPL_THEMES"]
        elif (whichField == "socioeconomic"):
            cviScore = onerow["RPL_THEME1"]
        elif (whichField == "Household Composition & Disability"):
            cviScore = onerow["RPL_THEME2"]
        elif (whichField == "Minority Status & Language"):
            cviScore = onerow["RPL_THEME3"]
        elif (whichField == "Housing Type & Transportation"):
            cviScore = onerow["RPL_THEME4"]
        
    return cviScore



############################### RACIAL POPULATION NUMBERS FOR THE TRACT ############################
############################### RACIAL POPULATION NUMBERS FOR THE TRACT ############################
############################### RACIAL POPULATION NUMBERS FOR THE TRACT ############################

jeffcoTractPopulations = pandas.read_csv(
    "D:\\Environmental Justice Docs\\ACSDT5Y2019.B02001_data_with_overlays_2021-07-02T051141.csv")

def getTractPopulations(tractGEOID, whichField):    
    population = -1
    rowzzz = jeffcoTractPopulations[(jeffcoTractPopulations.GEO_ID == tractGEOID)]#["B02001_001E"]
    for index, onerow in rowzzz.iterrows():
        if (whichField == "total population"):
            population = onerow["B02001_001E"]
        elif (whichField == "white population"):
            population = onerow["B02001_002E"]
        elif (whichField == "black population"):
            population = onerow["B02001_003E"]
        elif (whichField == "native american population"):
            population = onerow["B02001_004E"]
        elif (whichField == "asian population"):
            population = onerow["B02001_005E"]
        
    return population


################################## BRFSS HEALTH OUTCOMES DATA ##################################
lst_str_cols3 = ["MEASURE","LOCATIONNAME","LOCATIONID"]
dict_dtypes3 = {x : 'str'  for x in lst_str_cols3}

brfssHealthData = pandas.read_csv(
    "D:\\Environmental Justice Docs\\brfss_jeffco_only_outcomes_only_pcts.csv", dtype=dict_dtypes3)


def getBRFSSOutcome(tractGEOID, whichOutcome, whichField):    
    answer = "-1"
    if (whichField != "totpop"):   #notnull()
        rowzzz = brfssHealthData[(brfssHealthData.LOCATIONID == tractGEOID) & (brfssHealthData.MEASURE == whichOutcome)]
        for index, onerow in rowzzz.iterrows():
            if (whichField == "pct"):
                answer = str(onerow["DATA_VALUE_PCT"]) + "%"
#             elif (whichField == "totpop"):
#                 answer = str(onerow["TOTALPOPULATION"] )   
    else:
        rowzzz = brfssHealthData[(brfssHealthData.LOCATIONID == tractGEOID) ]
        for index, onerow in rowzzz.iterrows():
            if (whichField == "totpop"):
                answer = str(onerow["TOTALPOPULATION"] )   
        
    return answer


#BRFSS columns:    
    #"MEASURE","LOCATIONNAME","DATA_VALUE_PCT","TOTALPOPULATION","LOCATIONID"
    # "MEASURE" values are:
        # "Physical health not good for >=14 days among adults aged >=18 years"
        # "Cancer (excluding skin cancer) among adults aged >=18 years"
        # "All teeth lost among adults aged >=65 years"
        # "Mental health not good for >=14 days among adults aged >=18 years"
        # "Diagnosed diabetes among adults aged >=18 years"
        # "Stroke among adults aged >=18 years"
        # "Coronary heart disease among adults aged >=18 years"
        # "High cholesterol among adults aged >=18 years who have been screened in the past 5 years"
        # "Chronic obstructive pulmonary disease among adults aged >=18 years"
        # "High blood pressure among adults aged >=18 years"
        # "Arthritis among adults aged >=18 years"
        # "Current asthma among adults aged >=18 years"
        # "Chronic kidney disease among adults aged >=18 years"


        
##################### UAB ENCOUNTER COUNTS BY RACE AND TRACT ######################################

#TELLING PANDAS TO KEEP tract as a string so leading zeroes remain
lst_str_colsXX = ['TRACT_GEOID', 'UAB_RACE', 'UAB_DISEASE_CATEGORY']
# use dictionary comprehension to make dict of dtypes
dict_dtypesXX = {x : 'str'  for x in lst_str_colsXX}

#Columns are: 
    #"TRACT_GEOID","UAB_RACE","UAB_DISEASE_CATEGORY","UAB_PATS_THIS_DISEASE_CAT",
    #"UAB_ENCTRS_THIS_DISEASE_CAT",
    #"UAB_TOT_ENCTRS_THIS_GEO","UAB_TOT_PATS_THIS_GEO"
    
uab_encounters = pandas.read_csv(
    "D:\\Environmental Justice Docs\\all_diseases_ED_urgent_encs_since20150101.csv", 
    dtype=dict_dtypesXX)
    
#print(uab_encounters)

def getUABTractDiseases(tractGEOID, whichCategory, whichRace, whichField):    
    encounters = -1
    if (whichField == "disCatEnctrsTRACT"):
        rowzzz = uab_encounters[(uab_encounters.TRACT_GEOID == tractGEOID) & \
                                 (uab_encounters.UAB_DISEASE_CATEGORY == whichCategory) & \
                                 (uab_encounters.UAB_RACE == whichRace)]
        for index, onerow in rowzzz.iterrows():
            if (whichField == "disCatEnctrsTRACT"):
                encounters = onerow["UAB_ENCTRS_THIS_DISEASE_CAT"]

    else:
        rowzzz = uab_encounters[(uab_encounters.TRACT_GEOID == tractGEOID)]
        for index, onerow in rowzzz.iterrows():
            if (whichField == "disTotalEnctrsTRACT"):
                 encounters = onerow["UAB_TOT_ENCTRS_THIS_GEO"]
                    
    return encounters


#################### ADD POPULATION FEATURES TO THE CENSUS TRACT GEOJSON STRUCTURE ################
#################### ADD POPULATION FEATURES TO THE CENSUS TRACT GEOJSON STRUCTURE ################
#################### ADD POPULATION FEATURES TO THE CENSUS TRACT GEOJSON STRUCTURE ################

all_alabama_census_tracts = "D:\\Environmental Justice Docs\\AL_Census_Tracts_2016.geojson"

geo_json_alabama_census_tracts_data = json.load(open(all_alabama_census_tracts))




for i in range(len(geo_json_alabama_census_tracts_data["features"])): 
    thisTract = "1400000US" + str(geo_json_alabama_census_tracts_data["features"][i]["properties"]["GEOID"])
    plainTract = str(geo_json_alabama_census_tracts_data["features"][i]["properties"]["GEOID"])
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["POPULATION"] = \
        getTractPopulations(thisTract, "total population")
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["WHITE_POPULATION"] = \
        getTractPopulations(thisTract, "white population")
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["BLACK_POPULATION"] = \
        getTractPopulations(thisTract, "black population")
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["NATIVE_POPULATION"] = \
        getTractPopulations(thisTract, "native american population")
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["ASIAN_POPULATION"] = \
        getTractPopulations(thisTract, "asian population")

    ############################ opportunityStayInTractPercents
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["STAY_IN_TRACT_OF_BIRTH"] = \
        getOpportunityAtlasPercents(plainTract, "percentage")
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["NEIGHBORHOOD_NAME"] = \
        getOpportunityAtlasPercents(plainTract, "neighborhoodName")
    
    ########################### social vulnerability index scores

    geo_json_alabama_census_tracts_data["features"][i]["properties"]["SVI_OVERALL"] = \
        getCDC_SVI_Percents(plainTract, "overall")
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["SVI_SOSEC"] = \
        getCDC_SVI_Percents(plainTract, "socioeconomic")
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["SVI_HHCD"] = \
        getCDC_SVI_Percents(plainTract, "Household Composition & Disability")
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["SVI_MSLANG"] = \
        getCDC_SVI_Percents(plainTract, "Minority Status & Language")
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["SVI_HTT"] = \
        getCDC_SVI_Percents(plainTract, "Housing Type & Transportation")
    
    ########################## BRFSS health outcomes ####################################
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["PH_14DAYS"] = \
        getBRFSSOutcome(plainTract, "Physical health not good for >=14 days among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["CANCER_PCT"] = \
        getBRFSSOutcome(plainTract, "Cancer (excluding skin cancer) among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["TEETH_LOSS65"] = \
        getBRFSSOutcome(plainTract, "All teeth lost among adults aged >=65 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["MNTLHLTH_14DAYS"] = \
        getBRFSSOutcome(plainTract, "Mental health not good for >=14 days among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["DIABETES"] = \
        getBRFSSOutcome(plainTract, "Diagnosed diabetes among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["STROKE"] = \
        getBRFSSOutcome(plainTract, "Stroke among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["CHD"] = \
        getBRFSSOutcome(plainTract, "Coronary heart disease among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["HICHOL"] = \
        getBRFSSOutcome(plainTract, "High cholesterol among adults aged >=18 years who have been screened in the past 5 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["COPD"] = \
        getBRFSSOutcome(plainTract, "Chronic obstructive pulmonary disease among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["HIGHBP"] = \
        getBRFSSOutcome(plainTract, "High blood pressure among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["ARTHRITIS"] = \
        getBRFSSOutcome(plainTract, "Arthritis among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["ASTHMA"] = \
        getBRFSSOutcome(plainTract, "Current asthma among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["CKD"] = \
        getBRFSSOutcome(plainTract, "Chronic kidney disease among adults aged >=18 years", "pct") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["BRFSS_TRACT_TOTPOP"] = \
        getBRFSSOutcome(plainTract, "", "totpop") 
    
    ### TRACT DISEASES BY ENCOUNTER AND ICD CATEGORIES ###
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["TOTAL_TRACT_ENCS"] = \
        getUABTractDiseases(plainTract, "", "", "disTotalEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_NEOPLASM"] = \
        getUABTractDiseases(plainTract, "C_D_Neoplasms", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_NEOPLASM"] = \
        getUABTractDiseases(plainTract, "C_D_Neoplasms", "White", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_RESPIR"] = \
        getUABTractDiseases(plainTract, "J_Respiratory", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_RESPIR"] = \
        getUABTractDiseases(plainTract, "J_Respiratory", "White", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_NRVSYS"] = \
        getUABTractDiseases(plainTract, "G_Nervous System", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_NRVSYS"] = \
        getUABTractDiseases(plainTract, "G_Nervous System", "White", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_SKIN"] = \
        getUABTractDiseases(plainTract, "L_Skin", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_SKIN"] = \
        getUABTractDiseases(plainTract, "L_Skin", "White", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_INFPARA"] = \
        getUABTractDiseases(plainTract, "A_B_Infectious_Parasitic", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_INFPARA"] = \
        getUABTractDiseases(plainTract, "A_B_Infectious_Parasitic", "White", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_BLDIMU"] = \
        getUABTractDiseases(plainTract, "D_Blood_Immune", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_BLDIMU"] = \
        getUABTractDiseases(plainTract, "D_Blood_Immune", "White", "disCatEnctrsTRACT")     
                                                                     
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_METABOL"] = \
        getUABTractDiseases(plainTract, "E_Metabolic", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_METABOL"] = \
        getUABTractDiseases(plainTract, "E_Metabolic", "White", "disCatEnctrsTRACT") 
                                                                     
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_MENBEH"] = \
        getUABTractDiseases(plainTract, "F_Mental_Behavioral", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_MENBEH"] = \
        getUABTractDiseases(plainTract, "F_Mental_Behavioral", "White", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_EARMAST"] = \
        getUABTractDiseases(plainTract, "H_Ear_Mastoid", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_EARMAST"] = \
        getUABTractDiseases(plainTract, "H_Ear_Mastoid", "White", "disCatEnctrsTRACT")     
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_EYEADEX"] = \
        getUABTractDiseases(plainTract, "H_Eye_Adnexa", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_EYEADEX"] = \
        getUABTractDiseases(plainTract, "H_Eye_Adnexa", "White", "disCatEnctrsTRACT")    
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_CIRCUL"] = \
        getUABTractDiseases(plainTract, "I_Circulatory", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_CIRCUL"] = \
        getUABTractDiseases(plainTract, "I_Circulatory", "White", "disCatEnctrsTRACT")  
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_BLKCAT_DIGEST"] = \
        getUABTractDiseases(plainTract, "K_Digestive", "Black", "disCatEnctrsTRACT") 
    
    geo_json_alabama_census_tracts_data["features"][i]["properties"]["UAB_WHTCAT_DIGEST"] = \
        getUABTractDiseases(plainTract, "K_Digestive", "White", "disCatEnctrsTRACT") 


# A_B_Infectious_Parasitic
# D_Blood_Immune
# E_Metabolic
# F_Mental_Behavioral
# H_Ear_Mastoid
# H_Eye_Adnexa
# I_Circulatory
# K_Digestive

# M_Musculoskeletal
# N_Genitourinary
# O_Pregnancy_Childbirth
# Q_Congenital_Genetic
# R_Abnormal_Findings
# S_T_Injury_External
# U07_Uncertain_Etiology
# V_Y_External_Causes
# XXX_Unknown
# Z_Health_Status_Factors
 
    
print("This cell has completed")    
    
###############################END OF DATA CELL #1 ####################################################

# %%
tractMap = folium.Map(location=[33.5186, -86.8014], zoom_start=12,tiles="Stamen Toner")
    
censusTractLayer = folium.FeatureGroup(name="Census Tracts", show=False)


folium.GeoJson(geo_json_alabama_census_tracts_data,
               name = 'Census Tract',
               style_function = lambda x: {'fillColor': 'lightgray','color': 'red','weight': 2},
#                popup = folium.GeoJsonPopup(
#                     fields=('NAMELSAD', 'GEOID', 'NEIGHBORHOOD_NAME', 'POPULATION', "WHITE_POPULATION", 
#                                 "BLACK_POPULATION", "NATIVE_POPULATION", "ASIAN_POPULATION", 
#                                 "STAY_IN_TRACT_OF_BIRTH","SVI_OVERALL", "SVI_SOSEC", "SVI_HHCD",
#                                 "SVI_MSLANG", "SVI_HTT", "CANCER_PCT", ),
#                     aliases=('Tract Name','Geoid', 'Neighborhood','Tract Total Population', 'White Population', 
#                                  'Black Population', "Native American Population", "Asian Population", 
#                                  '% Remain in this Tract as Adults', 'Overall Social Vulnerability Score (SVI)',
#                                  'Socioeconomic SVI', 'Household Composition & Disability SVI',
#                                  'Minority Status & Language', 'Housing Type & Transportation',
#                                  'Cancer (excluding skin cancer) among adults aged >=18 years',) ),
               highlight_function=lambda x: {"fillOpacity": 0.8},
               zoom_on_click=False,
               show = False).add_to(censusTractLayer)


for i in range(len(geo_json_alabama_census_tracts_data["features"])): 
    
    lat = geo_json_alabama_census_tracts_data["features"][i]["properties"]["INTPTLAT"]
    long = geo_json_alabama_census_tracts_data["features"][i]["properties"]["INTPTLON"]
#     nameslad = geo_json_alabama_census_tracts_data["features"][i]["properties"]["NAMELSAD"]
#     geoid = geo_json_alabama_census_tracts_data["features"][i]["properties"]["GEOID"]
#     population = geo_json_alabama_census_tracts_data["features"][i]["properties"]["POPULATION"]
#     whitePopulation = geo_json_alabama_census_tracts_data["features"][i]["properties"]["WHITE_POPULATION"]
#     blackPopulation = geo_json_alabama_census_tracts_data["features"][i]["properties"]["BLACK_POPULATION"]
#     nativePopulation = geo_json_alabama_census_tracts_data["features"][i]["properties"]["NATIVE_POPULATION"]
#     asianPopulation = geo_json_alabama_census_tracts_data["features"][i]["properties"]["ASIAN_POPULATION"]
#     tractIdentifier = geo_json_alabama_census_tracts_data["features"][i]["properties"]["NAME"]
    
    iframe = folium.IFrame(
                html=popupMaker(geo_json_alabama_census_tracts_data["features"][i]["properties"]),
                width=IFRAME_WIDTH_SETTING,
                height=IFRAME_HEIGHT_SETTING)

    popup = folium.Popup(iframe) #, max_width=MAX_IFRAME_WIDTH)
    
    folium.CircleMarker(
        location=[lat, long],
        radius=5,
        popup = popup,        
        color='orange',
        fill=True,
        fill_color='orange',
        fill_opacity=0.7,
        parse_html=True).add_to(censusTractLayer)

censusTractLayer.add_to(tractMap)

#tractMap

tractMap.save('censustractlayeronly.html')

print("This cell has completed work")

# %%
################################## 1938 REDLINING HOLC LAYER #########################################
################################## 1938 REDLINING HOLC LAYER #########################################
################################## 1938 REDLINING HOLC LAYER #########################################



redliningLayer = folium.FeatureGroup(name="Home Owners Loan Corporation/Redlining Map of Birmingham, 1938")

geojson_this_map = "D:\\Environmental Justice Docs\\ALBirmingham1937REDLINING.geojson"
geo_json_loaded_data = json.load(open(geojson_this_map))


def get_grade_color(feature):
    areaGrade = feature['properties']['holc_grade']
    if (areaGrade == "A"):
        return '#117A65'
    elif (areaGrade == "B"):
        return '#F1C40F'
    elif (areaGrade == "C"):
        return '#3498DB'
    elif (areaGrade == "D"):
        return '#E74C3C'
    else:
        return '##F5F5F5'


folium.GeoJson(
    geo_json_loaded_data, 
    style_function=lambda feature: {
        'fillColor': get_grade_color(feature),
        'color': 'black',
        'weight': 0.7,
    },
    highlight_function=lambda x: {"fillOpacity": 0.8},
).add_to(redliningLayer)


iframe = folium.IFrame(
                html="""
             <nobr><h4>Bombings at Dynamite Hill</h4></nobr>             
             <p>"By the 1940s, black families were trying to purchase homes in 
             segregated white areas of Birmingham. The local Ku Klux Klan began a 
             terror campaign against black families attempting to move to the west 
             side of Center Street, sometimes firing shots or bombs at houses, 
             or lighting a home's door on fire. </p>
             <p>"Center Street became known as Dynamite Hill 
             because of these attacks. 
             From the late 1940s to the 1960s over 40 unsolved bombings occurred in 
             Birmingham. Klan members specifically targeted civil rights lawyer Arthur Shores 
             who lived in Birmingham. Some families refused to leave, 
             instead tolerating the attacks in an effort to support desegregation efforts."
             </p>
             <p> Source: Wikipedia contributors. (2021, April 26). Bombingham. 
             In Wikipedia, The Free Encyclopedia. Retrieved 19:11, July 23, 2021, from 
             https://en.wikipedia.org/w/index.php?title=Bombingham&oldid=1020021779 </p>
            """,
                width=300,
                height=400)

popup = folium.Popup(iframe,
                     max_width=1000)

    
folium.Marker(
    location=[33.522767528525954, -86.83560917301112],
    popup = popup,
    icon=folium.Icon(icon="bomb", prefix="fa", icon_color="white", color="darkred")
    
 ).add_to(redliningLayer)



folium.Marker(
    location=[33.51720364343945, -86.81494368465926],
    popup='<nobr><h4>Bombing at 16th Street Baptist Church</h4></nobr>',
    icon=folium.Icon(icon="bomb", prefix="fa", icon_color="white", color="darkred")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)

######################### 1971 LOCATIONS OF AQ MONITOR ###############################

folium.Marker(
    location=[33.59361973207573, -86.76906643976936],
    popup='<nobr><h4>Tarrant AQ Monitor, 1971 EPA Shutdown</h4></nobr>',
    icon=folium.Icon(icon="wind", icon_color="white", color="black", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)

folium.Marker(
    location=[33.55449062253169, -86.75251589632286],
    popup='<nobr><h4>Woodlawn AQ Monitor, 1971 EPA Shutdown</h4></nobr>',
    icon=folium.Icon(icon="cloud-sun",  icon_color="white", color="black", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)

folium.Marker(
    location=[33.53674582002504, -86.70017090574774],
    popup='<nobr><h4>Irondale AQ Monitor, 1971 EPA Shutdown</h4></nobr>',
    icon=folium.Icon(icon="wind", icon_color="white", color="black", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)

folium.Marker(
    location=[33.476241887502006, -86.72305588905334],
    popup='<nobr><h4>Mountain Brook AQ Monitor, 1971 EPA Shutdown</h4></nobr>',
    icon=folium.Icon(icon="cloud-sun",  icon_color="white", color="black", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)

folium.Marker(
    location=[33.39095248563371, -86.97836704634933],
    popup='<nobr><h4>Bessemer AQ Monitor, 1971 EPA Shutdown</h4></nobr>',
    icon=folium.Icon(icon="wind",  icon_color="white", color="black", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)

folium.Marker(
    location=[33.473682383865786, -86.92154435954834],
    popup='<nobr><h4>Fairfield AQ Monitor, 1971 EPA Shutdown</h4></nobr>',
    icon=folium.Icon(icon="smog",  icon_color="white", color="black", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)

folium.Marker(
    location=[33.48966665669335, -86.86702606725538],
    popup='<nobr><h4>West End AQ Monitor, 1971 EPA Shutdown</h4></nobr>',
    icon=folium.Icon(icon="wind",  icon_color="white", color="black", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)

folium.Marker(
    location=[33.519654126078976, -86.81123611965839],
    popup='<nobr><h4>Downtown AQ Monitor, 1971 EPA Shutdown</h4></nobr>',
    icon=folium.Icon(icon="wind",  icon_color="white", color="black", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)

folium.Marker(
    location=[33.553584563266945, -86.82289089668421],
    popup='<nobr><h4>North Birmingham AQ Monitor, 1971 EPA Shutdown</h4></nobr>',
    icon=folium.Icon(icon="wind", icon_color="white", color="black", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)

#Tarrant AQ Monitor 1971: 33.59361973207573, -86.76906643976936
#Woodlawn AQ Monitor 1971: 33.55449062253169, -86.75251589632286
#Irondale: 33.53674582002504, -86.70017090574774
#Mountain Brook: 33.476241887502006, -86.72305588905334
#Bessemer: 33.39095248563371, -86.97836704634933
#Fairfield: 33.473682383865786, -86.92154435954834
#West End: 33.48966665669335, -86.86702606725538
#Downtown: 33.519654126078976, -86.81123611965839
#North Birmingham: 33.553584563266945, -86.82289089668421


########### INTERSTATE CONSTRUCTION MARKERS ########################

iframe = folium.IFrame(
                html="""
             <nobr><h4>East Birmingham</h4></nobr>             
             <p>"In several instances, the interstate highways bisect historically 
             black neighborhoods. On Birmingham’s east side, Interstate 59 departs 
             from its generally northeast to southwest trajectory to loop north 
             and bisect the predominantly black portion of East Birmingham. 
             While the East Birmingham neighborhood through which the interstate was routed was 
             predominantly black, the neighborhoods lying to the south were predominantly white.  
             This routing of the interstate permitted the predominantly white Woodlawn neighborhood 
             to be largely bypassed by the interstate while retaining connections to the interstate 
             at its eastern and northern edges. Not surprisingly, the Woodlawn Chamber of 
             Commerce, which represented the many businesses in that neighborhood, 
             favored this route. </p>
             <p>"From a traffic-engineering viewpoint, 
             bypassing the Woodlawn neighborhood was not an easy achievement as 
             it required a sharp turn in the highway,thereby reducing the interstate’s 
             speed limit and increasing the danger of an accident as automobiles and 
             large commercial trucks, accustomed to traveling sixty or more miles per hour, 
             had to slow to forty-five miles per hour to negotiate the bend in the road."</p>
             <br />
             <p>Source: From Racial Zoning to Community Empowerment The Interstate Highway System and the 
             African American Community in Birmingham, Alabama by Charles E. Connerly</p></br>
             <p>Journal of Planning Education and Research 22:99-114</p>
             <p>DOI: 10.1177/0739456X02238441</p>
             <p>© 2002 Association of Collegiate Schools of Planning</p>
            """,
                width=300,
                height=400)

popup = folium.Popup(iframe,
                     max_width=1000)


folium.Marker(
    location=[33.544443344780994, -86.75876413771668], 
    popup=popup,
    icon=folium.Icon(icon="car", icon_color="white", color="darkpurple", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)




iframe = folium.IFrame(
                html="""
             <nobr><h4>East Lake</h4></nobr>             
             <p>"Further east from East Birmingham lies another black neighborhood, 
             located in the East Lake community, through which Interstate 59 ran. 
             Once again, the interstate takes an upward bend as it traverses this black neighborhood, 
             thereby avoiding a more southerly route that would have taken it through Wahouma Park, 
             a city park that separated this black neighborhood from the white neighborhoods to the south."</p>
             <br />
             <p>Source: From Racial Zoning to Community Empowerment The Interstate Highway System and the 
             African American Community in Birmingham, Alabama by Charles E. Connerly</p></br>
             <p>Journal of Planning Education and Research 22:99-114</p>
             <p>DOI: 10.1177/0739456X02238441</p>
             <p>© 2002 Association of Collegiate Schools of Planning</p>
            """,
                width=300,
                height=400)

popup = folium.Popup(iframe,
                     max_width=1000)


folium.Marker(
    location=[33.5583202581402, -86.74039637012476], 
    popup=popup,
    icon=folium.Icon(icon="car", icon_color="white", color="darkpurple", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)






iframe = folium.IFrame(
                html="""
             <nobr><h4>Smithfield</h4></nobr>             
             <p>"On Birmingham’s west side, the Highway Department constructed interstates 
             through black neighborhoods such as Smithfield in a manner that reinforced 
             racial segregation. Smithfield, which lay just west of downtown Birmingham, 
             was one of the more affluent black neighborhoods in Birmingham in 1960. </p>
             <p>"Since the late nineteenth century, Smithfield had been the home of many of Birmingham’s 
             black professionals and remained so into the late 1950s, as members of Birmingham’s 
             black elite began building new ranch-style homes along the 1000 and 
             1100 block of North Center Street on top of a hill with a good view of the city.</p> 
             <p>"Interstate 59 was routed through the middle of this newly developing suburban-style area, 
             thereby forcing its residents to move elsewhere."</p>
             <br />
             <p>Source: From Racial Zoning to Community Empowerment The Interstate Highway System and the 
             African American Community in Birmingham, Alabama by Charles E. Connerly</p></br>
             <p>Journal of Planning Education and Research 22:99-114</p>
             <p>DOI: 10.1177/0739456X02238441</p>
             <p>© 2002 Association of Collegiate Schools of Planning</p>
            """,
                width=300,
                height=400)

popup = folium.Popup(iframe,
                     max_width=1000)


folium.Marker(
    location=[33.52126249994297, -86.8281582457215], 
    popup=popup,
    icon=folium.Icon(icon="car", icon_color="white", color="darkpurple", prefix="fa")
    #data.iloc[i]['name'],
 ).add_to(redliningLayer)


redliningLayer.add_to(tractMap)

#tractMap

# %%
############################ BIRMINGHAM COMMUNITY LAYER ############################################
############################ BIRMINGHAM COMMUNITY LAYER ############################################
############################ BIRMINGHAM COMMUNITY LAYER ############################################


birminghamCommunityLayer = folium.FeatureGroup(name="Birmingham Communities (collection of neighborhoods)", show=False)

birminghamCommunities = "D:\\Environmental Justice Docs\\birmingham_community.geojson"

geo_json_loaded_data = json.load(open(birminghamCommunities))

# folium.GeoJson(geo_json_loaded_data, style_function=lambda feature: {
#                               'fillColor': '#FFFFFF',
#                               'color': 'black',
#                               'weight': 0.5,
# }).add_to(birminghamNeighborhoodsLayer)

folium.GeoJson(geo_json_loaded_data,
               name = 'Community',
               style_function = lambda x: {'fillColor': 'lightgreen','color': 'darkturquoise','weight': 2},
               highlight_function=lambda x: {"fillOpacity": 0.8},
               tooltip = folium.GeoJsonTooltip(fields=('NAME',),
                                               aliases=('Community',)),
               show = False).add_to(birminghamCommunityLayer)



birminghamCommunityLayer.add_to(tractMap)

# %%
############################ BIRMINGHAM NEIGHBORHOOD LAYER ############################################
############################ BIRMINGHAM NEIGHBORHOOD LAYER ############################################
############################ BIRMINGHAM NEIGHBORHOOD LAYER ############################################


r = random.random()
b = random.random()
g = random.random()
color = (r, g, b)

birminghamNeighborhoodLayer = folium.FeatureGroup(name="Birmingham Neighborhoods", show=False)

birminghamNeighborhoods = "D:\\Environmental Justice Docs\\neighborhoods.geojson"

geo_json_loaded_data = json.load(open(birminghamNeighborhoods))

# folium.GeoJson(geo_json_loaded_data, style_function=lambda feature: {
#                               'fillColor': '#FFFFFF',
#                               'color': 'black',
#                               'weight': 0.5,
# }).add_to(birminghamNeighborhoodsLayer)

folium.GeoJson(geo_json_loaded_data,
               name = 'Neighborhood',
               style_function = lambda x: {'fillColor': 'cadetblue', 'color': 'black','weight': 2},
               highlight_function=lambda x: {"fillOpacity": 0.8},
               tooltip = folium.GeoJsonTooltip(fields=('NAME',),
                                               aliases=('Neighborhood',)),
               show = False).add_to(birminghamNeighborhoodLayer)



birminghamNeighborhoodLayer.add_to(tractMap)

# %%
################################## EPA LANDFILL MARKERS LAYER #########################################
################################## EPA LANDFILL MARKERS LAYER #########################################
################################## EPA LANDFILL MARKERS LAYER #########################################

landfills = folium.FeatureGroup(name="EPA Landfills", show=False)

jeffco_landfills = pandas.read_csv(
    "D:\\Environmental Justice Docs\\EPA_LANDFILLs_Alabama_March2021Dataset - DETAILED SHEET.csv")

jeffco_landfills_clean = jeffco_landfills[(jeffco_landfills.Latitude.notnull() & \
                                             jeffco_landfills.Longitude.notnull())]

for index, row in jeffco_landfills_clean.iterrows():
    #print(row['Landfill Name'])
    popup = f"""
            <nobr><h3>EPA LandFill</h3></nobr>
            <p> {row['Landfill Name']}</p> 
            <p> {row['Physical Address']}</p>
            <p> {row['Zip Code']}</p>
            """
    
#"<p>str(row['Landfill Name']) + " " + str(row['Physical Address']) + " " + str(row['City']) + " " + \
#str(row['County']) + " " + str(row['Zip Code'])
    
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup,
        icon=folium.Icon(icon="trash-alt", icon_color="black", color="lightblue", prefix="fa")
        #data.iloc[i]['name'],
     ).add_to(landfills)

    
landfills.add_to(tractMap)

# %%
################################## JCDH AIR POLLUTION SOURCES MARKERS LAYER #########################################
################################## JCDH AIR POLLUTION SOURCES MARKERS LAYER #########################################
################################## JCDH AIR POLLUTION SOURCES MARKERS LAYER #########################################

jcdh_air_polluters = folium.FeatureGroup(name="JCDH Air Pollution Sources", show=False)

jeffco_air_pollution_sources = pandas.read_csv("D:\\Environmental Justice Docs\\birmingham_air_polluters_with_geocodings.csv")

dataframe = jeffco_air_pollution_sources[(jeffco_air_pollution_sources.MTCHADR_MATCHEDADDRESS.notnull())]

for index, row in dataframe.iterrows():
    
#     html=f"""
#         <p> {row['COMPANY']}</p> 
#         <p> {row['SUBMITTEDADDRESS']}</p>
#         """
    
    popup = f"""
            <nobr><h3>JCDH Air Pollution Source</h3></nobr>
            <p> {row['COMPANY']}</p> 
            <p> {row['SUBMITTEDADDRESS']}</p>            
            """
    
    #iframe = folium.IFrame(html=html, width=250, height=250)
    #popup = folium.Popup(iframe, max_width=50) 
    
    folium.CircleMarker(location=[row['YCORD'], row['XCORD']],
        radius=5,
        popup=popup,
        color='black',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(jcdh_air_polluters) 
    
jcdh_air_polluters.add_to(tractMap)

# %%
################################## SANITARY SEWER OVERFLOWS MARKERS LAYER #########################################
################################## SANITARY SEWER OVERFLOWS MARKERS LAYER #########################################
################################## SANITARY SEWER OVERFLOWS MARKERS LAYER #########################################


sanitarySewerOverflows = folium.FeatureGroup(name="Jeffco Envir. Sanitary Sewer Overflows", show=False)

jeffco_sanitary_sewer_overflows = \
    pandas.read_csv("D:\\Environmental Justice Docs\\CLEANED OverflowAdvisoriesJeffersonCountyDownloaded202107021426.csv")

dataframe = jeffco_sanitary_sewer_overflows[(jeffco_sanitary_sewer_overflows.X.notnull() & \
                                             jeffco_sanitary_sewer_overflows.Y.notnull())]

#print(dataframe)

for index, row in dataframe.iterrows():
    
#     html=f"""
#         <p> {row['Location']}</p> 
#         <p> {row['City']}</p>
#         """
    
    popup = f"""
            <nobr><h3>Sanitary Sewer Overflow</h3></nobr>
            <p> {row['Location']}</p> 
            <p> {row['City']}</p>  
            <p> {row['Zip']}</p>
            <p> {row['Reason']}</p>
            <p> {row['Date']}</p>
            """
    
    folium.CircleMarker(location=[row['X'], row['Y']],
        radius=5,
        popup=popup,
        color='green',
        fill=True,
        fill_color='black',
        fill_opacity=0.7,
        parse_html=False).add_to(sanitarySewerOverflows) 
    
    
sanitarySewerOverflows.add_to(tractMap)

# %%
################## EPA BROWNFIELDS/CLEANUPS/HAZ SITES MARKERS LAYER #########################################
################## EPA BROWNFIELDS/CLEANUPS/HAZ SITES MARKERS LAYER #########################################
################## EPA BROWNFIELDS/CLEANUPS/HAZ SITES MARKERS LAYER #########################################
    
brownfieldsCleanupsHazadous_EPA_JEFFCO = folium.FeatureGroup(name="EPA Brownfields, Cleanups, Hazardous Sites", show=False)


brownfieldsCleanupsHazadous = \
    pandas.read_csv("D:\\Environmental Justice Docs\\CLEANED Jeffco_Birmingham EPA Brownfields Cleanups Hazardous_basic_search_result.csv")

dataframe = brownfieldsCleanupsHazadous

# dataframe = jeffco_sanitary_sewer_overflows[(jeffco_sanitary_sewer_overflows.X.notnull() & \
#                                              jeffco_sanitary_sewer_overflows.Y.notnull())]

#print(dataframe)

for index, row in dataframe.iterrows():
    
#     html=f"""
#         <p> {row['Cleanup Name']}</p> 
#         <p> {row['Location Address']}</p>
#         <p> {row['City Name']}</p>
#        """
    popup = f"""
            <nobr><h3>EPA Brownfield/Cleanup Site</h3></nobr>
            <p> {row['Cleanup Name']}</p> 
            <p> {row['Location Address']}</p>  
            <p> {row['City Name']}</p>
            <p> {row['Postal Code']}</p>            
            """
    
    folium.CircleMarker(location=[row['X'], row['Y']],
        radius=5,
        popup=popup,
        color='pink',
        fill=True,
        fill_color='brown',
        fill_opacity=0.7,
        parse_html=False).add_to(brownfieldsCleanupsHazadous_EPA_JEFFCO) 
    
    
brownfieldsCleanupsHazadous_EPA_JEFFCO.add_to(tractMap)

# %%
################## EPA RECENT COMPLIANCE VIOLATIONS MARKERS LAYER #########################################
################## EPA RECENT COMPLIANCE VIOLATIONS MARKERS LAYER #########################################
################## EPA RECENT COMPLIANCE VIOLATIONS MARKERS LAYER #########################################


EPAEchoSearchRecentViolations = folium.FeatureGroup(
    name="EPA Enforcement and Compliance History Online (Recent violations only)", show=False)


ECHORecentViolators = \
    pandas.read_csv("D:\\Environmental Justice Docs\\BHAM_76VIOLATIONS_Data_Download_ECHO_7_17_2021_60f299ab960df.csv")

dataframe = ECHORecentViolators

#print(dataframe)



for index, row in dataframe.iterrows():
    
#     html=f"""
#         <p> {row['FacName']}</p> 
#         <p> {row['FacStreet']}</p>
#         <p> {row['FacZip']}</p>
#         """
    
    popup = f"""
            <nobr><h3>EPA Recent Violator</h3></nobr>
            <p> {row['FacName']}</p> 
            <p> {row['FacStreet']}</p>  
            <p> {row['FacZip']}</p>                      
            """
    #print(html)
    
    folium.CircleMarker(location=[row['FacLat'], row['FacLong']],
        radius=5,
        popup=popup,
        color='purple',
        fill=True,
        fill_color='white',
        fill_opacity=0.7,
        parse_html=False).add_to(EPAEchoSearchRecentViolations) 
    
    
EPAEchoSearchRecentViolations.add_to(tractMap)

# %%
################## EPA TRI FACILITIES MARKERS LAYER #########################################
################## EPA TRI FACILITIES MARKERS LAYER #########################################
################## EPA TRI FACILITIES MARKERS LAYER #########################################


EPATRISites = folium.FeatureGroup(name="EPA Toxic Release Inventory (TRI) Sites", show=False)


ECHORecentViolators = \
    pandas.read_csv("D:\\Environmental Justice Docs\\LEAN CLEAN tri_2019_al.csv")

dataframe = ECHORecentViolators

#print(dataframe)



for index, row in dataframe.iterrows():    
    
    popup = f"""
            <nobr><h3>EPA TRI Site</h3></nobr>
            <p> {row['1. YEAR']}</p> 
            <p> {row['17. STANDARD PARENT CO NAME']}</p>
            <p> {row['4. FACILITY NAME']}</p>  
            <p> {row['5. STREET ADDRESS']}</p>   
            <p> {row['6. CITY']}</p>  
            <p> {row['7. COUNTY']}</p> 
            <p> {row['9. ZIP']}</p>            
            <p><nobr> Industrial Sector: {row['20. INDUSTRY SECTOR']}</nobr></p>            
            """
#38. CLEAN AIR ACT CHEMICAL 39. CLASSIFICATION 42. CARCINOGEN
    
    folium.CircleMarker(location=[row['12. LATITUDE'], row['13. LONGITUDE']],
        radius=5,
        popup=popup,
        color='black',
        fill=True,
        fill_color='yellow',
        fill_opacity=0.7,
        parse_html=False).add_to(EPATRISites) 
    
    
EPATRISites.add_to(tractMap)

# %%
folium.LayerControl().add_to(tractMap)
tractMap.save('jeffersonCountyEnvornmentalJustice202107.html')
